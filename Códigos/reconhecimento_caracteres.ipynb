# %%
pip install pytesseract

# %%
pip install tesseract-ocr-por

# %%
# !apt-get update
# !apt-get install tesseract-ocr-por
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,742 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import cv2
import pytesseract as pt

# %%
img=cv2.imread('teste_tesseract.png')

# %%
print(pt.pytesseract.image_to_string(img, lang='por'))
# Out:
# UNIVERSIDADE ESTADUAL DO MARANHÃO
# CENTRO DE CIÊNCIAS TECNOLÓGICAS - cr
# DEPARTAMENTO DE ENGENHARIA DE COMPUTAÇÃO
#
# Visão computacional usando Python e OpenCV — Abordagem introdutória
# Prof. Dr. Lúcio F. A. Campos
#
# SÃO LUÍS - MA
# 2026
